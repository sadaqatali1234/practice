# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame(np.array([[10,11,12,13],[20,21,22,23]]))
df
# Out:
#     0   1   2   3
# 0  10  11  12  13
# 1  20  21  22  23

# %%
df1=pd.DataFrame([pd.Series(np.arange(10,15)),
                    pd.Series(np.arange(15,20))])


df1
# Out:
#     0   1   2   3   4
# 0  10  11  12  13  14
# 1  15  16  17  18  19

# %%
s1= pd.Series(np.arange(1,6,1))
s2=pd.Series(np.arange(6,11,1))
df2=pd.DataFrame({'boys':s1,'girls':s2})
df2
# Out:
#    boys  girls
# 0     1      6
# 1     2      7
# 2     3      8
# 3     4      9
# 4     5     10

# %%
data={'name':["asad","saad","fahad","ali"],'age':[23,24,23,21],"grades":["A","B","A","B"]}
data=pd.DataFrame(data)
data
# Out:
#     name  age grades
# 0   asad   23      A
# 1   saad   24      B
# 2  fahad   23      A
# 3    ali   21      B

# %%
df3=pd.DataFrame(np.array([[10,11],[20,21]]),columns=["apples","oranges"])

df3
# Out:
#    apples  oranges
# 0      10       11
# 1      20       21

# %%
df4=pd.DataFrame(np.array([[10,11,12,13],[20,21,22,23]]),index=["apples","oranges"],columns=["Mon","Tue","Wed","Thu"])

df4
# Out:
#          Mon  Tue  Wed  Thu
# apples    10   11   12   13
# oranges   20   21   22   23

# %%
s3=pd.Series(np.arange(12,14),index=[1,2])
dfs=pd.DataFrame({"c1":s1,"c2":s2,"c3":s3})
dfs
# Out:
#    c1  c2    c3
# 0   1   6   NaN
# 1   2   7  12.0
# 2   3   8  13.0
# 3   4   9   NaN
# 4   5  10   NaN

# %%
data={'State':["Ohio","Ohio","Ohio","Nevenda","Nevenda","Nevenda"],
      "Year":[200,2001,2002,2001,2002,2003],
      "pop":[1.5,1.7,3.6,2.4,2.9,3.2]}
frame=pd.DataFrame(data)
frame
# Out:
#      State  Year  pop
# 0     Ohio   200  1.5
# 1     Ohio  2001  1.7
# 2     Ohio  2002  3.6
# 3  Nevenda  2001  2.4
# 4  Nevenda  2002  2.9
# 5  Nevenda  2003  3.2

# %%
pd.DataFrame(frame,columns=["Year","State","pop"])
# Out:
#    Year    State  pop
# 0   200     Ohio  1.5
# 1  2001     Ohio  1.7
# 2  2002     Ohio  3.6
# 3  2001  Nevenda  2.4
# 4  2002  Nevenda  2.9
# 5  2003  Nevenda  3.2

# %%
frame.Year
# Out:
# 0     200
# 1    2001
# 2    2002
# 3    2001
# 4    2002
# 5    2003
# Name: Year, dtype: int64

# %%
frame.State
# Out:
# 0       Ohio
# 1       Ohio
# 2       Ohio
# 3    Nevenda
# 4    Nevenda
# 5    Nevenda
# Name: State, dtype: object

# %%
frame["pop"]
# Out:
# 0    1.5
# 1    1.7
# 2    3.6
# 3    2.4
# 4    2.9
# 5    3.2
# Name: pop, dtype: float64

# %%
frame2=pd.DataFrame(data,columns=["Year","State","pop","debt"],
                   index=["one","two","three","four","five","six"])
frame2
# Out:
#        Year    State  pop debt
# one     200     Ohio  1.5  NaN
# two    2001     Ohio  1.7  NaN
# three  2002     Ohio  3.6  NaN
# four   2001  Nevenda  2.4  NaN
# five   2002  Nevenda  2.9  NaN
# six    2003  Nevenda  3.2  NaN

# %%
frame2.debt=100
frame2
# Out:
#        Year    State  pop  debt
# one     200     Ohio  1.5   100
# two    2001     Ohio  1.7   100
# three  2002     Ohio  3.6   100
# four   2001  Nevenda  2.4   100
# five   2002  Nevenda  2.9   100
# six    2003  Nevenda  3.2   100

# %%
frame2["debt"]=np.arange(6)
frame2
# Out:
#        Year    State  pop  debt
# one     200     Ohio  1.5     0
# two    2001     Ohio  1.7     1
# three  2002     Ohio  3.6     2
# four   2001  Nevenda  2.4     3
# five   2002  Nevenda  2.9     4
# six    2003  Nevenda  3.2     5

# %%
val=pd.Series([-1.2,-1.5,-1.7],index=['two','four','five'])

# %%
frame2["debt"]=val
frame2
# Out:
#        Year    State  pop  debt
# one     200     Ohio  1.5   NaN
# two    2001     Ohio  1.7  -1.2
# three  2002     Ohio  3.6   NaN
# four   2001  Nevenda  2.4  -1.5
# five   2002  Nevenda  2.9  -1.7
# six    2003  Nevenda  3.2   NaN

# %%
frame2['eastern']=np.arange(6)
frame2
# Out:
#        Year    State  pop  debt  eastern
# one     200     Ohio  1.5   NaN        0
# two    2001     Ohio  1.7  -1.2        1
# three  2002     Ohio  3.6   NaN        2
# four   2001  Nevenda  2.4  -1.5        3
# five   2002  Nevenda  2.9  -1.7        4
# six    2003  Nevenda  3.2   NaN        5

# %%
frame2['eastern']=frame2.State=="Ohio"
frame2
# Out:
#        Year    State  pop  debt  eastern
# one     200     Ohio  1.5   NaN     True
# two    2001     Ohio  1.7  -1.2     True
# three  2002     Ohio  3.6   NaN     True
# four   2001  Nevenda  2.4  -1.5    False
# five   2002  Nevenda  2.9  -1.7    False
# six    2003  Nevenda  3.2   NaN    False

# %%
frame2['greaterThan2']=frame2['pop']>2
frame2
# Out:
#        Year    State  pop  debt  eastern  greaterThan2
# one     200     Ohio  1.5   NaN     True         False
# two    2001     Ohio  1.7  -1.2     True         False
# three  2002     Ohio  3.6   NaN     True          True
# four   2001  Nevenda  2.4  -1.5    False          True
# five   2002  Nevenda  2.9  -1.7    False          True
# six    2003  Nevenda  3.2   NaN    False          True

# %%
del frame2['eastern']

# %%
frame2
# Out:
#        Year    State  pop  debt  greaterThan2
# one     200     Ohio  1.5   NaN         False
# two    2001     Ohio  1.7  -1.2         False
# three  2002     Ohio  3.6   NaN          True
# four   2001  Nevenda  2.4  -1.5          True
# five   2002  Nevenda  2.9  -1.7          True
# six    2003  Nevenda  3.2   NaN          True

# %%
data={'name':["Asad","Fahad","Saad","Ali"],
     "age":[23,34,23,21],
     "AiForEveryone":[89,78,90,98],
     "python":[78,89,87,89],
     "git":[90,98,87,86],
     "numpy":[98,87,98,99]}
data=pd.DataFrame(data)
data
# Out:
#     name  age  AiForEveryone  python  git  numpy
# 0   Asad   23             89      78   90     98
# 1  Fahad   34             78      89   98     87
# 2   Saad   23             90      87   87     98
# 3    Ali   21             98      89   86     99

# %%
data["total"]=data[['AiForEveryone','python','git','numpy']].sum(axis=1)
data
# Out:
#     name  age  AiForEveryone  python  git  numpy  total
# 0   Asad   23             89      78   90     98    355
# 1  Fahad   34             78      89   98     87    352
# 2   Saad   23             90      87   87     98    362
# 3    Ali   21             98      89   86     99    372

# %%
data["Total"]=data['AiForEveryone']+data['python']+data['git']+data['numpy']
data
# Out:
#     name  age  AiForEveryone  python  git  numpy  total  Total
# 0   Asad   23             89      78   90     98    355    355
# 1  Fahad   34             78      89   98     87    352    352
# 2   Saad   23             90      87   87     98    362    362
# 3    Ali   21             98      89   86     99    372    372

# %%
del data['total']

# %%
data
# Out:
#     name  age  AiForEveryone  python  git  numpy  Total
# 0   Asad   23             89      78   90     98    355
# 1  Fahad   34             78      89   98     87    352
# 2   Saad   23             90      87   87     98    362
# 3    Ali   21             98      89   86     99    372

# %%
pop={"Nevenda":{2001:2.4,2002:2.9},"Ohio":{2000:1.5,2001:1.7,2002:3.6}}
df3=pd.DataFrame(pop)
df3
# Out:
#       Nevenda  Ohio
# 2001      2.4   1.7
# 2002      2.9   3.6
# 2000      NaN   1.5

# %%
df3.T
# Out:
#          2001  2002  2000
# Nevenda   2.4   2.9   NaN
# Ohio      1.7   3.6   1.5

# %%
df3
# Out:
#       Nevenda  Ohio
# 2001      2.4   1.7
# 2002      2.9   3.6
# 2000      NaN   1.5

# %%
pop1=pd.DataFrame(pop,index=[2001,2002,2003])
pop1
# Out:
#       Nevenda  Ohio
# 2001      2.4   1.7
# 2002      2.9   3.6
# 2003      NaN   NaN

# %%
pdata={"Ohio":df3['Ohio'][:-1],
      "Nevenda":df3['Nevenda'][:2]}
pd.DataFrame(pdata)
# Out:
#       Ohio  Nevenda
# 2001   1.7      2.4
# 2002   3.6      2.9

# %%
df3.index.name='year'
df3.columns.name='state_names'
df3
# Out:
# state_names  Nevenda  Ohio
# year
# 2001             2.4   1.7
# 2002             2.9   3.6
# 2000             NaN   1.5

# %%
obj=pd.Series(range(3),index=['a','b','c'])
obj
# Out:
# a    0
# b    1
# c    2
# dtype: int64

# %%
index=obj.index
index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
index[1:]
# Out:
# Index(['b', 'c'], dtype='object')

# %%
index[1]='d'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-8be6e68dba2d> in <module>
# ----> 1 index[1]='d'
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in __setitem__(self, key, value)
#    3908
#    3909     def __setitem__(self, key, value):
# -> 3910         raise TypeError("Index does not support mutable operations")
#    3911
#    3912     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
labels=pd.Index(['a','b','c','d','e','f'])

# %%
labels
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f'], dtype='object')

# %%
labels[0]="z"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-67e3b5a4c1cd> in <module>
# ----> 1 labels[0]="z"
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in __setitem__(self, key, value)
#    3908
#    3909     def __setitem__(self, key, value):
# -> 3910         raise TypeError("Index does not support mutable operations")
#    3911
#    3912     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
print(frame)
# Out:
#      State  Year  pop
# 0     Ohio   200  1.5
# 1     Ohio  2001  1.7
# 2     Ohio  2002  3.6
# 3  Nevenda  2001  2.4
# 4  Nevenda  2002  2.9
# 5  Nevenda  2003  3.2

# %%
frame.index=labels
frame
# Out:
#      State  Year  pop
# a     Ohio   200  1.5
# b     Ohio  2001  1.7
# c     Ohio  2002  3.6
# d  Nevenda  2001  2.4
# e  Nevenda  2002  2.9
# f  Nevenda  2003  3.2

# %%
frame.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f'], dtype='object')

# %%
frame.columns
# Out:
# Index(['State', 'Year', 'pop'], dtype='object')

# %%
frame2['debt']=np.arange(6)
print("The frame is ",end="\n\n")
print(frame2,end="\n\n")
print("The row indices are",end="\n\n")
print(frame2.index,end="\n\n")
print("The columns indices are",end="\n\n")
print(frame2.columns)
# Out:
# The frame is
#
#        Year    State  pop  debt  greaterThan2
# one     200     Ohio  1.5     0         False
# two    2001     Ohio  1.7     1         False
# three  2002     Ohio  3.6     2          True
# four   2001  Nevenda  2.4     3          True
# five   2002  Nevenda  2.9     4          True
# six    2003  Nevenda  3.2     5          True
#
# The row indices are
#
# Index(['one', 'two', 'three', 'four', 'five', 'six'], dtype='object')
#
# The columns indices are
#
# Index(['Year', 'State', 'pop', 'debt', 'greaterThan2'], dtype='object')

# %%
reindex_frame=frame2.reindex(['five','two','three','six','four','one','seven'])

# %%
reindex_frame
# Out:
#          Year    State  pop  debt greaterThan2
# five   2002.0  Nevenda  2.9   4.0         True
# two    2001.0     Ohio  1.7   1.0        False
# three  2002.0     Ohio  3.6   2.0         True
# six    2003.0  Nevenda  3.2   5.0         True
# four   2001.0  Nevenda  2.4   3.0         True
# one     200.0     Ohio  1.5   0.0        False
# seven     NaN      NaN  NaN   NaN          NaN

# %%
 reindex_frame=frame2.reindex(columns=['pop','Year','imports','debt','export','State'])
reindex_frame
# Out:
#        pop  Year  imports  debt  export    State
# one    1.5   200      NaN     0     NaN     Ohio
# two    1.7  2001      NaN     1     NaN     Ohio
# three  3.6  2002      NaN     2     NaN     Ohio
# four   2.4  2001      NaN     3     NaN  Nevenda
# five   2.9  2002      NaN     4     NaN  Nevenda
# six    3.2  2003      NaN     5     NaN  Nevenda

# %%
row_dropped_frame=reindex_frame.drop(['three','six'])
row_dropped_frame
# Out:
#       pop  Year  imports  debt  export    State
# one   1.5   200      NaN     0     NaN     Ohio
# two   1.7  2001      NaN     1     NaN     Ohio
# four  2.4  2001      NaN     3     NaN  Nevenda
# five  2.9  2002      NaN     4     NaN  Nevenda

# %%
col_dropped_frame=reindex_frame.drop(['imports','export'],axis=1)
col_dropped_frame
# Out:
#        pop  Year  debt    State
# one    1.5   200     0     Ohio
# two    1.7  2001     1     Ohio
# three  3.6  2002     2     Ohio
# four   2.4  2001     3  Nevenda
# five   2.9  2002     4  Nevenda
# six    3.2  2003     5  Nevenda

# %%
index=["Firefox","Chrome","Safari","IE10","Konerque"]
df = pd.DataFrame({"http_status":[200,200,404,404,301],
                     "response_time":[0.02,0.04,0.07,0.08,1.0]},index=index)
df
# Out:
#           http_status  response_time
# Firefox           200           0.02
# Chrome            200           0.04
# Safari            404           0.07
# IE10              404           0.08
# Konerque          301           1.00

# %%
new_index=['Safari','Icewesal','Comodo Dragon','IE10','Chrome']
df.reindex(new_index)
# Out:
#                http_status  response_time
# Safari               404.0           0.07
# Icewesal               NaN            NaN
# Comodo Dragon          NaN            NaN
# IE10                 404.0           0.08
# Chrome               200.0           0.04

# %%
df.reindex(new_index,fill_value=0)
# Out:
#                http_status  response_time
# Safari                 404           0.07
# Icewesal                 0           0.00
# Comodo Dragon            0           0.00
# IE10                   404           0.08
# Chrome                 200           0.04

# %%
df.reindex(new_index,fill_value="missing")
# Out:
#               http_status response_time
# Safari                404          0.07
# Icewesal          missing       missing
# Comodo Dragon     missing       missing
# IE10                  404          0.08
# Chrome                200          0.04

# %%
df.reindex(columns=['http_status','user_agent'])
# Out:
#           http_status  user_agent
# Firefox           200         NaN
# Chrome            200         NaN
# Safari            404         NaN
# IE10              404         NaN
# Konerque          301         NaN

# %%
df.reindex(['http_status','user_agent','status'],axis="columns")
# Out:
#           http_status  user_agent  status
# Firefox           200         NaN     NaN
# Chrome            200         NaN     NaN
# Safari            404         NaN     NaN
# IE10              404         NaN     NaN
# Konerque          301         NaN     NaN

# %%
date_index=pd.date_range('1/1/2010',periods=6,freq="D")
df2=pd.DataFrame({"price":[100,20,30,np.nan,200,399]},index=date_index)
df2
# Out:
#             price
# 2010-01-01  100.0
# 2010-01-02   20.0
# 2010-01-03   30.0
# 2010-01-04    NaN
# 2010-01-05  200.0
# 2010-01-06  399.0

# %%
date_index2=pd.date_range('12/29/2009',periods=10,freq="D")
df2.reindex(date_index2)
# Out:
#             price
# 2009-12-29    NaN
# 2009-12-30    NaN
# 2009-12-31    NaN
# 2010-01-01  100.0
# 2010-01-02   20.0
# 2010-01-03   30.0
# 2010-01-04    NaN
# 2010-01-05  200.0
# 2010-01-06  399.0
# 2010-01-07    NaN

# %%
df2.reindex(date_index2,method="bfill")
# Out:
#             price
# 2009-12-29  100.0
# 2009-12-30  100.0
# 2009-12-31  100.0
# 2010-01-01  100.0
# 2010-01-02   20.0
# 2010-01-03   30.0
# 2010-01-04    NaN
# 2010-01-05  200.0
# 2010-01-06  399.0
# 2010-01-07    NaN

# %%
naDf=pd.DataFrame({"ages":[2,3,4,5,6,np.NaN,7,],"gender":['m','f','m','m',np.nan,'f','m']})
naDf
# Out:
#    ages gender
# 0   2.0      m
# 1   3.0      f
# 2   4.0      m
# 3   5.0      m
# 4   6.0    NaN
# 5   NaN      f
# 6   7.0      m

# %%
data= pd.DataFrame((np.arange(40).reshape(10,4)),
index=['ohio','nevenda','washington','london','newyork','utah','texas','califorinia','colorado','neberska'],
columns=['jan','feb','mar','apr'])



data
# Out:
#              jan  feb  mar  apr
# ohio           0    1    2    3
# nevenda        4    5    6    7
# washington     8    9   10   11
# london        12   13   14   15
# newyork       16   17   18   19
# utah          20   21   22   23
# texas         24   25   26   27
# califorinia   28   29   30   31
# colorado      32   33   34   35
# neberska      36   37   38   39

# %%
data['jan']
# Out:
# ohio            0
# nevenda         4
# washington      8
# london         12
# newyork        16
# utah           20
# texas          24
# califorinia    28
# colorado       32
# neberska       36
# Name: jan, dtype: int32

# %%
data[['jan','apr']]
# Out:
#              jan  apr
# ohio           0    3
# nevenda        4    7
# washington     8   11
# london        12   15
# newyork       16   19
# utah          20   23
# texas         24   27
# califorinia   28   31
# colorado      32   35
# neberska      36   39

# %%
data[:2]
# Out:
#          jan  feb  mar  apr
# ohio       0    1    2    3
# nevenda    4    5    6    7

# %%
data['newyork':'colorado']
# Out:
#              jan  feb  mar  apr
# newyork       16   17   18   19
# utah          20   21   22   23
# texas         24   25   26   27
# califorinia   28   29   30   31
# colorado      32   33   34   35

# %%
data[2:6,0:2
    
    ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-835da9f8478c> in <module>
# ----> 1 data[2:6,0:2
#       2
#       3     ]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2644                 )
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#    2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# ...

# %%
data['newyork':'texas','utah':'colorado']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-2227092fc052> in <module>
# ----> 1 data['newyork':'texas','utah':'colorado']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2644                 )
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#    2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# ...

# %%
data.loc['newyork':'texas','jan':'mar']
# Out:
#          jan  feb  mar
# newyork   16   17   18
# utah      20   21   22
# texas     24   25   26

# %%
data.iloc[2:6,0:2]
# Out:
#             jan  feb
# washington    8    9
# london       12   13
# newyork      16   17
# utah         20   21

# %%
a=pd.DataFrame({'p':[2,4,6,7]})
a.div(2)
# Out:
#      p
# 0  1.0
# 1  2.0
# 2  3.0
# 3  3.5

# %%
a=pd.DataFrame({'p':[2,4,6,7]})
a.rdiv(2)
# Out:
#           p
# 0  1.000000
# 1  0.500000
# 2  0.333333
# 3  0.285714

# %%
a.add(2)
# Out:
#    p
# 0  4
# 1  6
# 2  8
# 3  9

# %%
a.radd(2)
# Out:
#    p
# 0  4
# 1  6
# 2  8
# 3  9

# %%
a.pow(2)
# Out:
#     p
# 0   4
# 1  16
# 2  36
# 3  49

# %%
a.rpow(4)
# Out:
#        p
# 0     16
# 1    256
# 2   4096
# 3  16384

# %%
a.sub(2)
# Out:
#    p
# 0  0
# 1  2
# 2  4
# 3  5

# %%
data['mar']>15
# Out:
# ohio           False
# nevenda        False
# washington     False
# london         False
# newyork         True
# utah            True
# texas           True
# califorinia     True
# colorado        True
# neberska        True
# Name: mar, dtype: bool

# %%
data[data['mar']>20
    
    ]
# Out:
#              jan  feb  mar  apr
# utah          20   21   22   23
# texas         24   25   26   27
# califorinia   28   29   30   31
# colorado      32   33   34   35
# neberska      36   37   38   39

# %%
data[data<5]=0
data
# Out:
#              jan  feb  mar  apr
# ohio           0    0    0    0
# nevenda        0    5    6    7
# washington     8    9   10   11
# london        12   13   14   15
# newyork       16   17   18   19
# utah          20   21   22   23
# texas         24   25   26   27
# califorinia   28   29   30   31
# colorado      32   33   34   35
# neberska      36   37   38   39

# %%
frame=np.abs(pd.DataFrame(np.random.randn(4,3),
                         columns=list('bde'),
                         index=['Utah','Ohio','Texas','Oregan']))
frame
# Out:
#                b         d         e
# Utah    0.521369  1.210299  1.131544
# Ohio    0.207757  1.404389  1.250964
# Texas   0.575647  0.931913  0.001125
# Oregan  0.991160  0.023275  0.882016

# %%
f = lambda x : x.max()-x.min()

# %%
frame.apply(f,axis='rows')
# Out:
# b    0.783403
# d    1.381114
# e    1.249838
# dtype: float64

# %%
frame.apply(f,axis='columns')
# Out:
# Utah      0.688930
# Ohio      1.196632
# Texas     0.930788
# Oregan    0.967884
# dtype: float64

# %%
(lambda x :x*x*x) (10)
# Out:
# 1000

# %%
df=pd.DataFrame({"id":[1,2,3,4,4],
                "name":['Asad','Munshi','Fahad','Saad','Tariq'],
                "age":[20,23,24,25,26],
                 "income":[5000,6000,2000,1000,1500]})
df
# Out:
#    id    name  age  income
# 0   1    Asad   20    5000
# 1   2  Munshi   23    6000
# 2   3   Fahad   24    2000
# 3   4    Saad   25    1000
# 4   4   Tariq   26    1500

# %%
#df['age']=[3+age for age in df['age']]
#df

# %%
#df['age']=df['age']+3
#df

# %%
df['age']=df.apply(lambda x :x['age']+3,axis='columns')

# %%
df
# Out:
#    id    name  age  income
# 0   1    Asad   23    5000
# 1   2  Munshi   26    6000
# 2   3   Fahad   27    2000
# 3   4    Saad   28    1000
# 4   4   Tariq   29    1500

# %%
df['age']=df['age'].apply(lambda x : x+3)
df
# Out:
#    id    name  age  income
# 0   1    Asad   26    5000
# 1   2  Munshi   29    6000
# 2   3   Fahad   30    2000
# 3   4    Saad   31    1000
# 4   4   Tariq   32    1500

# %%
list(filter(lambda x: x>26,df['age']))
# Out:
# [29, 30, 31, 32]

# %%
df['income']=list(map(lambda x :int(x+x*0.20),df['income']))

# %%
df
# Out:
#    id    name  age  income
# 0   1    Asad   26    6000
# 1   2  Munshi   29    7200
# 2   3   Fahad   30    2400
# 3   4    Saad   31    1200
# 4   4   Tariq   32    1800

# %%
df['category']=df['age'].apply(lambda x : 'Adult'if x >29 else 'Child')
df
# Out:
#    id    name  age  income category
# 0   1    Asad   26    6000    Child
# 1   2  Munshi   29    7200    Child
# 2   3   Fahad   30    2400    Adult
# 3   4    Saad   31    1200    Adult
# 4   4   Tariq   32    1800    Adult

# %%
import functools

# %%
functools.reduce(lambda a,b:a+b,df['income'])
# Out:
# 18600
